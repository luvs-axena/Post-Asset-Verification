# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Analytics Case Study 1-Post Asset Verification.csv')

# %%
df['Pin Code'].nunique()
# Out:
# 5394

# %%
df.dtypes
# Out:
# Customer ID                             int64
# Date of disbursal of loan      datetime64[ns]
# Payment type                           object
# Area Code                              object
# Pin Code                               object
# State                                  object
# Dealer Type                            object
# Product Type                           object
# Tenure                                float64
# Rate Of Interest                      float64
# EMI                                   float64
# Processing Fee                        float64
# Asset Cost                              int64
# Loan Amount                             int64
# Gender                                 object
# Qualification                          object
# Employement Type                       object
# Residence Type                         object
# Age                                   float64
# CIBIL Score                           float64
# ...

# %%
# Out:
#        Customer ID Date of disbursal of loan Payment type  Area Code  \
# 0                0                 2/13/2020          ACH       3075
# 1                1                  6/2/2020          ADM       3075
# 2                2                 10/2/2020          ADM       3075
# 3                3                 10/2/2020          ADM       3075
# 4                4                 10/2/2020          ADM       3075
# ...            ...                       ...          ...        ...
# 11697        11697                 2/28/2021          ADM       3052
# 11698        11698                 2/28/2021          ACH       3052
# 11699        11699                 2/28/2021          ACH       3052
# 11700        11700                  9/2/2021          ACH       3074
# 11701        11701                  2/2/2021          ADM       3074
#
#        Pin Code State Dealer Type Product Type    Tenure  Rate Of Interest  \
# ...

# %%
df['Date of disbursal of loan'] = pd.to_datetime(df['Date of disbursal of loan'])

# %%
df.dtypes
# Out:
# Customer ID                             int64
# Date of disbursal of loan      datetime64[ns]
# Payment type                           object
# Area Code                               int64
# Pin Code                                int64
# State                                  object
# Dealer Type                            object
# Product Type                           object
# Tenure                                float64
# Rate Of Interest                      float64
# EMI                                   float64
# Processing Fee                        float64
# Asset Cost                              int64
# Loan Amount                             int64
# Gender                                 object
# Qualification                          object
# Employement Type                       object
# Residence Type                         object
# Age                                   float64
# CIBIL Score                           float64
# ...

# %%
df['Area Code']= df['Area Code'].astype(str)
df['Pin Code']= df['Pin Code'].astype(str)

# %%
df.describe()
# Out:
#        Customer ID        Tenure  Rate Of Interest           EMI  \
# count  11702.00000  11702.000000      11702.000000  11702.000000
# mean    5850.50000      0.433095          0.053421      0.144393
# std     3378.22076      0.124747          0.958336      0.058075
# min        0.00000      0.000000         -4.921127      0.000000
# 25%     2925.25000      0.352941         -0.555137      0.103964
# 50%     5850.50000      0.352941          0.258525      0.138930
# 75%     8775.75000      0.588235          0.595897      0.178081
# max    11701.00000      1.000000          3.017038      1.000000
#
#        Processing Fee     Asset Cost    Loan Amount           Age  \
# count    11702.000000   11702.000000   11702.000000  11698.000000
# mean        -0.033912   85622.271578   67222.861648      0.368793
# std          1.013351   21326.356207   13855.472488      0.220920
# min         -1.726064   52700.000000   50000.000000      0.000000
# ...

# %%
df.skew()[['Loan Amount','Asset Cost','EMI','Net Salary']]
# Out:
# Loan Amount     1.168428
# Asset Cost      1.176346
# EMI             1.369546
# Net Salary     14.300964
# dtype: float64

# %%
df.skew()
# Out:
# CIBIL Score                    -1.170476
# Pin Code                       -0.381662
# Rate Of Interest               -0.290034
# Processing Fee                 -0.160980
# Customer ID                     0.000000
# Area Code                       0.336665
# Tenure                          0.391335
# Age                             0.428119
# Net Internal Rate of Return     0.879544
# Loan Amount                     1.168428
# Asset Cost                      1.176346
# EMI                             1.369546
# Target Variable                 3.229072
# Net Salary                     14.300964
# dtype: float64

# %% [markdown]
# EMI , Asset Cost , Loan Amount , CIBIL Score , Net Salary are skewed

# %%
df.isnull().mean()*100
# Out:
# Customer ID                     0.000000
# Date of disbursal of loan       0.000000
# Payment type                    0.000000
# Area Code                       0.000000
# Pin Code                        0.000000
# State                           0.000000
# Dealer Type                     0.000000
# Product Type                    0.000000
# Tenure                          0.000000
# Rate Of Interest                0.000000
# EMI                             0.000000
# Processing Fee                  0.000000
# Asset Cost                      0.000000
# Loan Amount                     0.000000
# Gender                          0.034182
# Qualification                   0.034182
# Employement Type                0.034182
# Residence Type                  0.034182
# Age                             0.034182
# CIBIL Score                    60.681935
# Net Salary                      0.000000
# Net Internal Rate of Return     0.000000
# Target Variable                 0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                       0
# Date of disbursal of loan         0
# Payment type                      0
# Area Code                         0
# Pin Code                          0
# State                             0
# Dealer Type                       0
# Product Type                      0
# Tenure                            0
# Rate Of Interest                  0
# EMI                               0
# Processing Fee                    0
# Asset Cost                        0
# Loan Amount                       0
# Gender                            4
# Qualification                     4
# Employement Type                  4
# Residence Type                    4
# Age                               4
# CIBIL Score                    7101
# Net Salary                        0
# Net Internal Rate of Return       0
# Target Variable                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Date of disbursal of loan', 'Payment type', 'Area Code',
#        'Pin Code', 'State', 'Dealer Type', 'Product Type', 'Tenure',
#        'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Gender', 'Qualification', 'Employement Type',
#        'Residence Type', 'Age', 'CIBIL Score', 'Net Salary',
#        'Net Internal Rate of Return', 'Target Variable'],
#       dtype='object')

# %%
df['Target Variable'].value_counts()
# Out:
# 0    10825
# 1      877
# Name: Target Variable, dtype: int64

# %% [markdown]
# We may have to do undersampling and oversampling

# %%
sns.countplot(x='Payment type',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Payment type', ylabel='count'>

# %%
promoted = df[df['Target Variable']==1].groupby('Payment type')['Target Variable'].count().reset_index()

# %%
 [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5a984b00d78a> in <module>
# ----> 1 [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
#
# NameError: name 'tot' is not defined

# %%
promoted

# %%
df[df['Target Variable']==1].groupby('Payment type')['Target Variable'].count().reset_index()

# %%
tot

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Payment type')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Payment type')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Payment type",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Payment type", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
promoted['Target Variable']
# Out:
# 0       8.389089
# 1       6.939260
# 2    1128.571429
# 3       5.785124
# Name: Target Variable, dtype: float64

# %%
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]

# %%
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]

# %%
tot
# Out:
#   Payment type  Target Variable
# 0          ACH            100.0
# 1          ADM            100.0
# 2          DAS            100.0
# 3          DRE            100.0
# 4         ENCH            100.0
# 5          PDC            100.0

# %%
promoted
# Out:
#   Payment type  Target Variable
# 0          ACH         8.389089
# 1          ADM         6.939260
# 2          DRE      1128.571429
# 3         ENCH         5.785124

# %%
sns.countplot(x='State',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='State', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('State')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('State')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="State",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="State", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
df[df['Target Variable']==1].groupby('State')['Target Variable'].transform()
# Out:
#    State  Target Variable
# 0     AP               13
# 1     AS               18
# 2     BR               19
# 3     CG               11
# 4     CH                2
# 5     DL               16
# 6     GJ               36
# 7     HA               23
# 8     JH               15
# 9     KA               70
# 10    KL               31
# 11    MH              115
# 12    MP               37
# 13    OR               31
# 14    PB               25
# 15    PY                9
# 16    RJ               17
# 17    TN              255
# 18    UC               13
# 19    UP               60
# 20    WB               61

# %%
promoted
# Out:
#    State  Target Variable
# 0     AP         0.821226
# 1     AS         3.066440
# 2     BR         3.682171
# 3     CG        34.375000
# 4     CH         9.090909
# 5     DL         9.937888
# 6     GJ        19.251337
# 7     HA         8.646617
# 8     JH        10.489510
# 9     KA        40.229885
# 10    KL        47.692308
# 11    MH        17.503805
# 12    MP        16.157205
# 13    OR         5.272109
# 14    PB      2500.000000
# 15    PY         2.922078
# 16    RJ         2.397743
# 17    TN        71.629213
# 18    UC        44.827586
# 19    UP         6.888634
# 20    WB         3.326063

# %%
tot
# Out:
#    State  Target Variable
# 0     AP            100.0
# 1     AS            100.0
# 2     BR            100.0
# 3     CG            100.0
# 4     CH            100.0
# 5     DL            100.0
# 6     GJ            100.0
# 7     HA            100.0
# 8     HP            100.0
# 9     JH            100.0
# 10    JK            100.0
# 11    KA            100.0
# 12    KL            100.0
# 13    MH            100.0
# 14    MN            100.0
# 15    MP            100.0
# 16    OR            100.0
# 17    PB            100.0
# 18    PY            100.0
# 19    RJ            100.0
# 20    TN            100.0
# 21    TR            100.0
# 22    UC            100.0
# 23    UP            100.0
# 24    WB            100.0

# %%
sns.countplot(x='Dealer Type',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Dealer Type', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Dealer Type')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Dealer Type')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Dealer Type",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Dealer Type", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
df[df['Target Variable']==1].groupby('Dealer Type')['Target Variable'].count()
# Out:
# Dealer Type
# ASC       289
# DEALER    588
# Name: Target Variable, dtype: int64

# %%
df.groupby('Dealer Type')['Target Variable'].count()
# Out:
# Dealer Type
# ASC       5305
# DEALER    6397
# Name: Target Variable, dtype: int64

# %%
promoted
# Out:
#   Dealer Type  Target Variable
# 0         ASC         5.447691
# 1      DEALER         9.191809

# %%
df.columns
# Out:
# Index(['Customer ID', 'Date of disbursal of loan', 'Payment type', 'Area Code',
#        'Pin Code', 'State', 'Dealer Type', 'Product Type', 'Tenure',
#        'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Gender', 'Qualification', 'Employement Type',
#        'Residence Type', 'Age', 'CIBIL Score', 'Net Salary',
#        'Net Internal Rate of Return', 'Target Variable'],
#       dtype='object')

# %%
tes=pd.DataFrame(df.groupby(['State','Target Variable']).count()['Customer ID']).transform(lambda x: (x/(df.groupby('State')['Target Variable'].count()))*100).reset_index()
tes['Column'] = 'State'
tes = tes.set_index(['Column','State','Target Variable'])

# %%
tes.reset_index()[tes.reset_index()['Target Variable']==1].sort_values(by='Customer ID',ascending=False)
# Out:
#    Column State  Target Variable  Customer ID
# 7   State    CG                1    34.375000
# 34  State    PY                1    31.034483
# 25  State    MH                1    19.557823
# 13  State    GJ                1    19.251337
# 41  State    UC                1    13.978495
# 38  State    TN                1    13.904035
# 23  State    KL                1    13.537118
# 28  State    MP                1    12.012987
# 21  State    KA                1    10.654490
# 11  State    DL                1     9.937888
# 9   State    CH                1     9.090909
# 15  State    HA                1     8.646617
# 18  State    JH                1     8.620690
# 32  State    PB                1     7.022472
# 43  State    UP                1     5.725191
# 45  State    WB                1     5.622120
# 30  State    OR                1     4.372355
# 5   State    BR                1     3.682171
# 3   State    AS                1     3.066440
# ...

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x='State',y='Customer ID',data=tes.reset_index(),hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='State', ylabel='Customer ID'>

# %%
tes=pd.DataFrame(df.groupby(['Qualification','Target Variable']).count()['Customer ID']).transform(lambda x: (x/(df.groupby('Qualification')['Target Variable'].count()))*100).reset_index()
tes['Column'] = 'Qualification'
tes = tes.set_index(['Column','Qualification','Target Variable'])

# %%
tes
# Out:
#                                              Customer ID
# Column        Qualification Target Variable
# Qualification HSC           0                  93.015093
#                             1                   6.984907
#               OTHERS        0                  92.825218
#                             1                   7.174782
#               PG            0                  91.866667
#                             1                   8.133333
#               SSC           0                  94.268920
#                             1                   5.731080
#               UG            0                  90.631283
#                             1                   9.368717

# %%
tes2=pd.DataFrame(df.groupby(['Area Code','Target Variable']).count()['Customer ID']).transform(lambda x: (x/(df.groupby('Area Code')['Target Variable'].count()))*100).reset_index()
tes2['Column'] = 'Area Code'
tes2 = tes2.set_index(['Column','Area Code','Target Variable'])

# %%
temp = tes2.reset_index()[tes2.reset_index()['Target Variable']==1].sort_values(by='Customer ID',ascending=False)

# %%
temp
# Out:
#         Column Area Code  Target Variable  Customer ID
# 27   Area Code      3015                1    34.375000
# 31   Area Code      3018                1    27.906977
# 52   Area Code      3030                1    27.586207
# 15   Area Code      3008                1    25.333333
# 106  Area Code      3061                1    24.742268
# ..         ...       ...              ...          ...
# 64   Area Code      3036                1     1.169591
# 108  Area Code      3064                1     1.098901
# 132  Area Code      3111                1     0.985222
# 33   Area Code      3019                1     0.380228
# 76   Area Code      3042                1     0.335570
#
# [65 rows x 4 columns]

# %%
sns.histplot(temp['Customer ID'])
# Out:
# <AxesSubplot:xlabel='Customer ID', ylabel='Count'>

# %% [markdown]
# Can be binned to Low Risk , Medium Risk, High Risk

# %%
tes
# Out:
#                                          Customer ID
# Column      Dealer Type Target Variable
# Dealer Type ASC         0                  94.552309
#                         1                   5.447691
#             DEALER      0                  90.808191
#                         1                   9.191809

# %%
df.groupby([df.dtypes])

# %%
tes = tes.reset_index()

# %%
tes['Columns'] = 'Dealer type'

# %%
tes
# Out:
#                                          Customer ID      Columns
# COlumns     Dealer Type Target Variable
# Dealer type ASC         0                  94.552309  Dealer type
#                         1                   5.447691  Dealer type
#             DEALER      0                  90.808191  Dealer type
#                         1                   9.191809  Dealer type

# %%
tes = tes.set_index(['COlumns','Dealer Type','Target Variable'])

# %%
tes2 = pd.DataFrame(df.groupby(['Product Type','Target Variable']).count()['Customer ID']).transform(lambda x: (x/(df.groupby('Product Type')['Target Variable'].count()))*100)

# %%
ne = pd.concat([tes,tes2])

# %%
ne
# Out:
#                                           Customer ID
# Column       Dealer Type Target Variable
# Dealer Type  ASC         0                  94.552309
#                          1                   5.447691
#              DEALER      0                  90.808191
#                          1                   9.191809
# Product Type EB          0                  75.000000
#                          1                  25.000000
#              MC          0                  94.000979
#                          1                   5.999021
#              MO          0                  93.432530
#                          1                   6.567470
#              SC          0                  91.120918
#                          1                   8.879082

# %%
pd.DataFrame(df.groupby(['Dealer Type','Target Variable']).count()['Customer ID']).iloc[0]
# Out:
# Customer ID    5016
# Name: (ASC, 0), dtype: int64

# %%
pd.DataFrame({'Variable':'Dealer Type',
              'Count' :(pd.DataFrame(df.groupby(['Dealer Type','Target Variable']).count()['Customer ID']).iloc[1] / pd.DataFrame(df.groupby(['Dealer Type','Target Variable']).count()['Customer ID']).iloc[0])*100})
# Out:
#                 Variable     Count
# Customer ID  Dealer Type  5.761563

# %%
sns.countplot(x='Product Type',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Product Type', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Product Type')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Product Type')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Product Type",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Product Type", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
sns.countplot(x='Gender',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Gender')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Gender')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Gender",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Gender", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
sns.countplot(x='Qualification',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Qualification', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Qualification')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Qualification')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Qualification",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Qualification", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
sns.countplot(x='Employement Type',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Employement Type', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Employement Type')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Employement Type')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Employement Type",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Employement Type", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
sns.countplot(x='Residence Type',data=df,hue='Target Variable')
# Out:
# <AxesSubplot:xlabel='Residence Type', ylabel='count'>

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Residence Type')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Residence Type')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Residence Type",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Residence Type", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
plt.figure(figsize=(14, 7))
tot = df.groupby('Area Code')['Target Variable'].count().reset_index()
promoted = df[df['Target Variable']==1].groupby('Area Code')['Target Variable'].count().reset_index()
promoted['Target Variable'] = [i / j * 100 for i,j in zip(promoted['Target Variable'], tot['Target Variable'])]
tot['Target Variable'] = [i / j * 100 for i,j in zip(tot['Target Variable'], tot['Target Variable'])]
bar2 = sns.barplot(x="Area Code",  y="Target Variable", data=tot, color='darkblue')
bar1= sns.barplot(x="Area Code", y="Target Variable", data=promoted, color='lightblue')
plt.show()

# %%
df.columns
# Out:
# Index(['Customer ID', 'Date of disbursal of loan', 'Payment type', 'Area Code',
#        'Pin Code', 'State', 'Dealer Type', 'Product Type', 'Tenure',
#        'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Gender', 'Qualification', 'Employement Type',
#        'Residence Type', 'Age', 'CIBIL Score', 'Net Salary',
#        'Net Internal Rate of Return', 'Target Variable'],
#       dtype='object')

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='EMI',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='EMI'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['EMI'],bins=50)
sns.distplot(df[df['Target Variable']==0]['EMI'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='EMI', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='EMI',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='EMI', ylabel='Count'>

# %%
df[df['EMI']>0.3]
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 28              28                2020-02-28          ADM      3058   843113
# 97              97                2020-08-02          ADM      3009   560093
# 103            103                2020-10-02          ADM      3009   562157
# 110            110                2020-02-26          ADM      3110   572121
# 119            119                2020-02-28          ADM      3025   575001
# ...            ...                       ...          ...       ...      ...
# 11467        11467                2021-02-15          ACH      3000   600101
# 11470        11470                2021-02-17          ACH      3000   635811
# 11506        11506                2021-02-20          ACH      3000   600099
# 11614        11614                2021-02-13          ADM      3078   742148
# 11691        11691                2021-02-27          ADM      3052   203394
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Processing Fee',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Processing Fee'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Processing Fee'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Processing Fee'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Processing Fee', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Processing Fee',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Processing Fee', ylabel='Count'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Asset Cost'],bins=20)
sns.distplot(df[df['Target Variable']==0]['Asset Cost'],bins=20,color='red')

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Asset Cost',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Asset Cost'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Asset Cost'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Asset Cost'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Asset Cost', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Asset Cost',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Asset Cost', ylabel='Count'>

# %%
df[df['Asset Cost']>138000]
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 1724          1724                2020-05-14          ADM      3078   735213
# 1725          1725                2020-05-13          ACH      3078   735216
# 1726          1726                2020-05-26          ADM      3078   713123
# 1730          1730                2020-05-19          ADM      3078   731237
# 1743          1743                2020-11-05          ADM      3088   768052
# ...            ...                       ...          ...       ...      ...
# 11618        11618                2021-02-18          ADM      3078   742134
# 11620        11620                2021-02-19          ACH      3078   721453
# 11626        11626                2021-02-16          ACH      3078   713101
# 11641        11641                2021-02-28          ADM      3078   713104
# 11647        11647                2021-02-28          ACH      3078   742212
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Loan Amount',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Loan Amount'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Loan Amount'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Loan Amount'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Loan Amount', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Loan Amount',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Loan Amount', ylabel='Count'>

# %%
df[df['Loan Amount']>105000]
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 212            212                2020-11-02          ACH      3001   606808
# 331            331                2020-02-15          ACH      3006   625018
# 402            402                2019-12-23          ADM      3078   721627
# 403            403                2019-12-23          ADM      3078   721648
# 1498          1498                2020-03-01          ACH      3054   741506
# ...            ...                       ...          ...       ...      ...
# 11616        11616                2021-02-17          ADM      3078   742202
# 11632        11632                2021-02-28          ACH      3078   721641
# 11641        11641                2021-02-28          ADM      3078   713104
# 11690        11690                2021-02-27          ADM      3052   250401
# 11698        11698                2021-02-28          ACH      3052   250002
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Age'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Age'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Age'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Age',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='CIBIL Score',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='CIBIL Score'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['CIBIL Score'],bins=50)
sns.distplot(df[df['Target Variable']==0]['CIBIL Score'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CIBIL Score', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='CIBIL Score',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='CIBIL Score', ylabel='Count'>

# %%
df[df['CIBIL Score']<-2.5]
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 78              78                2020-02-18          ADM      3053   822124
# 443            443                2019-04-12          ADM      3088   767017
# 550            550                2019-04-12          ADM      3052   203394
# 670            670                2019-12-25          ADM      3000   600101
# 873            873                2019-05-12          ADM      3047   126101
# ...            ...                       ...          ...       ...      ...
# 11190        11190                2020-11-28          ADM      3054   741502
# 11262        11262                2020-11-17          ADM      3078   742213
# 11304        11304                2020-09-12          ADM      3072   785693
# 11459        11459                2021-02-17          ADM      3000   603110
# 11518        11518                2021-05-02          ADM      3000   600050
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='CIBIL Score',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='CIBIL Score'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='CIBIL Score',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='CIBIL Score', ylabel='Count'>

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Net Salary',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Net Salary'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Net Salary'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Net Salary'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Net Salary', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Net Salary',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Net Salary', ylabel='Count'>

# %%
df
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 0                0                2020-02-13          ACH      3075   530041
# 1                1                2020-06-02          ADM      3075   532123
# 2                2                2020-10-02          ADM      3075   533218
# 3                3                2020-10-02          ADM      3075   532484
# 4                4                2020-10-02          ADM      3075   530046
# ...            ...                       ...          ...       ...      ...
# 11697        11697                2021-02-28          ADM      3052   245101
# 11698        11698                2021-02-28          ACH      3052   250002
# 11699        11699                2021-02-28          ACH      3052   250401
# 11700        11700                2021-09-02          ACH      3074   244601
# 11701        11701                2021-02-02          ADM      3074   244221
#
# ...

# %%
df[df['Net Salary']>2]
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 62              62                2020-02-18          ACH      3031   370110
# 92              92                2020-02-22          DRE      3009   563135
# 94              94                2020-02-26          ACH      3009   560037
# 169            169                2020-02-27          ADM      3014   474002
# 303            303                2020-02-28          ADM      3000   600044
# ...            ...                       ...          ...       ...      ...
# 11444        11444                2021-09-02          ADM      3000   600052
# 11456        11456                2021-02-28          ACH      3000   600118
# 11479        11479                2021-02-24          ADM      3000   600062
# 11658        11658                2021-02-28          ACH      3041   281406
# 11676        11676                2021-02-26          ACH      3035   251318
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Net Internal Rate of Return',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Net Internal Rate of Return'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Net Internal Rate of Return'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Net Internal Rate of Return'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Net Internal Rate of Return', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Net Internal Rate of Return',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Net Internal Rate of Return', ylabel='Count'>

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Tenure',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Tenure'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Tenure'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Tenure'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Tenure', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Tenure',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Tenure', ylabel='Count'>

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='Rate Of Interest',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='Rate Of Interest'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['Rate Of Interest'],bins=50)
sns.distplot(df[df['Target Variable']==0]['Rate Of Interest'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Rate Of Interest', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='Rate Of Interest',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='Rate Of Interest', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Date of disbursal of loan', 'Payment type', 'Area Code',
#        'Pin Code', 'State', 'Dealer Type', 'Product Type', 'Tenure',
#        'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Gender', 'Qualification', 'Employement Type',
#        'Residence Type', 'Age', 'CIBIL Score', 'Net Salary',
#        'Net Internal Rate of Return', 'Target Variable'],
#       dtype='object')

# %% [markdown]
# ## Binning on Area Code

# %%
temp['risk'] = pd.cut(temp['Customer ID'],bins=5,labels=[1,2,3,4,5])

# %%
risk_5 = list(temp[temp['risk']==5]['Area Code'])
risk_4 = list(temp[temp['risk']==4]['Area Code'])
risk_3 = list(temp[temp['risk']==3]['Area Code'])
risk_2 = list(temp[temp['risk']==2]['Area Code'])
risk_1 = list(temp[temp['risk']==1]['Area Code'])

# %%
df['area_risk'] = [5 if x in risk_5 else 4 if x in risk_4 else 3 if x in risk_3 else 2 if x in risk_2 else 1 if x in risk_1 else 1 for x in df['Area Code']]

# %%
df.groupby(['area_risk','Target Variable']).count()['Customer ID']
# Out:
# area_risk  Target Variable
# 1          0                  6846
#            1                   210
# 2          0                  2341
#            1                   255
# 3          0                  1162
#            1                   246
# 4          0                   320
#            1                   103
# 5          0                   156
#            1                    63
# Name: Customer ID, dtype: int64

# %% [markdown]
# ## Binning on Pin Code

# %%
tes3=pd.DataFrame(df.groupby(['Pin Code','Target Variable']).count()['Customer ID']).transform(lambda x: (x/(df.groupby('Pin Code')['Target Variable'].count()))*100).reset_index()
tes3['Column'] = 'Pin Code'
tes3 = tes3.set_index(['Column','Pin Code','Target Variable'])

# %%
tes3
# Out:
#                                    Customer ID
# Column   Pin Code Target Variable
# Pin Code 110002   0                      100.0
#          110003   0                      100.0
#          110006   0                      100.0
#          110007   0                      100.0
#          110008   0                      100.0
# ...                                        ...
#          855108   0                      100.0
#          855113   0                      100.0
#          855114   0                      100.0
#          855115   0                      100.0
#          855116   0                      100.0
#
# [5848 rows x 1 columns]

# %%
temp1 = tes3.reset_index()[tes3.reset_index()['Target Variable']==1].sort_values(by='Customer ID',ascending=False)

# %%
temp1
# Out:
#         Column Pin Code  Target Variable  Customer ID
# 5835  Pin Code   854333                1   100.000000
# 2963  Pin Code   580025                1   100.000000
# 5113  Pin Code   767061                1   100.000000
# 3138  Pin Code   600113                1   100.000000
# 3122  Pin Code   600094                1   100.000000
# ...        ...      ...              ...          ...
# 1020  Pin Code   313001                1     6.451613
# 685   Pin Code   244001                1     6.250000
# 1974  Pin Code   500055                1     5.555556
# 171   Pin Code   141001                1     5.555556
# 1000  Pin Code   311001                1     5.555556
#
# [704 rows x 4 columns]

# %%
temp1['risk'] = pd.cut(temp1['Customer ID'],bins=5,labels=[1,2,3,4,5])

# %%
riskp_5 = list(temp1[temp1['risk']==5]['Pin Code'])
riskp_4 = list(temp1[temp1['risk']==4]['Pin Code'])
riskp_3 = list(temp1[temp1['risk']==3]['Pin Code'])
riskp_2 = list(temp1[temp1['risk']==2]['Pin Code'])
riskp_1 = list(temp1[temp1['risk']==1]['Pin Code'])

# %%
df['pin_risk'] = [5 if x in riskp_5 else 4 if x in riskp_4 else 3 if x in riskp_3 else 2 if x in riskp_2 else 1 if x in riskp_1 else 1 for x in df['Pin Code']]

# %%
df.groupby(['pin_risk','Target Variable']).count()['Customer ID']
# Out:
# pin_risk  Target Variable
# 1         0                  10134
#           1                    156
# 2         0                    502
#           1                    230
# 3         0                    170
#           1                    175
# 4         0                     19
#           1                     45
# 5         1                    271
# Name: Customer ID, dtype: int64

# %% [markdown]
# ## Datetime conversion

# %%
df['Date of disbursal of loan'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df['Date of disbursal of loan']
# Out:
# 0       2020-02-13
# 1       2020-06-02
# 2       2020-10-02
# 3       2020-10-02
# 4       2020-10-02
#            ...
# 11697   2021-02-28
# 11698   2021-02-28
# 11699   2021-02-28
# 11700   2021-09-02
# 11701   2021-02-02
# Name: Date of disbursal of loan, Length: 11702, dtype: datetime64[ns]

# %%
df['no_of_days'] = (pd.to_datetime('2021-12-19') - df['Date of disbursal of loan']).dt.days

# %%
df
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 0                0                2020-02-13          ACH      3075   530041
# 1                1                2020-06-02          ADM      3075   532123
# 2                2                2020-10-02          ADM      3075   533218
# 3                3                2020-10-02          ADM      3075   532484
# 4                4                2020-10-02          ADM      3075   530046
# ...            ...                       ...          ...       ...      ...
# 11697        11697                2021-02-28          ADM      3052   245101
# 11698        11698                2021-02-28          ACH      3052   250002
# 11699        11699                2021-02-28          ACH      3052   250401
# 11700        11700                2021-09-02          ACH      3074   244601
# 11701        11701                2021-02-02          ADM      3074   244221
#
# ...

# %%
plt.figure(figsize=(14, 7))
sns.boxplot(x='Target Variable',y='no_of_days',data=df)
# Out:
# <AxesSubplot:xlabel='Target Variable', ylabel='no_of_days'>

# %%
plt.figure(figsize=(12, 8))

sns.distplot(df[df['Target Variable']==1]['no_of_days'],bins=50)
sns.distplot(df[df['Target Variable']==0]['no_of_days'],bins=50,color='red')
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='no_of_days', ylabel='Density'>

# %%
plt.figure(figsize=(14, 7))
sns.histplot(data=df,x='no_of_days',hue='Target Variable',kde=True)
# Out:
# <AxesSubplot:xlabel='no_of_days', ylabel='Count'>

# %%
df.dtypes
# Out:
# Customer ID                             int64
# Date of disbursal of loan      datetime64[ns]
# Payment type                           object
# Area Code                              object
# Pin Code                               object
# State                                  object
# Dealer Type                            object
# Product Type                           object
# Tenure                                float64
# Rate Of Interest                      float64
# EMI                                   float64
# Processing Fee                        float64
# Asset Cost                              int64
# Loan Amount                             int64
# Gender                                 object
# Qualification                          object
# Employement Type                       object
# Residence Type                         object
# Age                                   float64
# CIBIL Score                           float64
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Date of disbursal of loan', 'Payment type', 'Area Code',
#        'Pin Code', 'State', 'Dealer Type', 'Product Type', 'Tenure',
#        'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Gender', 'Qualification', 'Employement Type',
#        'Residence Type', 'Age', 'CIBIL Score', 'Net Salary',
#        'Net Internal Rate of Return', 'Target Variable', 'area_risk',
#        'pin_risk', 'no_of_days'],
#       dtype='object')

# %%
df_new = df.drop(['Customer ID','Area Code','Pin Code','Date of disbursal of loan','CIBIL Score'],axis=1)

# %%
df_new.isnull().sum()
# Out:
# Payment type                   0
# State                          0
# Dealer Type                    0
# Product Type                   0
# Tenure                         0
# Rate Of Interest               0
# EMI                            0
# Processing Fee                 0
# Asset Cost                     0
# Loan Amount                    0
# Gender                         4
# Qualification                  4
# Employement Type               4
# Residence Type                 4
# Age                            4
# Net Salary                     0
# Net Internal Rate of Return    0
# Target Variable                0
# area_risk                      0
# pin_risk                       0
# no_of_days                     0
# dtype: int64

# %%
df_new = df_new.dropna()

# %%
df_new1 = pd.get_dummies(df_new)

# %%
df_new1.columns
# Out:
# Index(['Tenure', 'Rate Of Interest', 'EMI', 'Processing Fee', 'Asset Cost',
#        'Loan Amount', 'Age', 'Net Salary', 'Net Internal Rate of Return',
#        'Target Variable', 'area_risk', 'pin_risk', 'no_of_days',
#        'Payment type_ACH', 'Payment type_ADM', 'Payment type_DAS',
#        'Payment type_DRE', 'Payment type_ENCH', 'Payment type_PDC', 'State_AP',
#        'State_AS', 'State_BR', 'State_CG', 'State_CH', 'State_DL', 'State_GJ',
#        'State_HA', 'State_HP', 'State_JH', 'State_JK', 'State_KA', 'State_KL',
#        'State_MH', 'State_MN', 'State_MP', 'State_OR', 'State_PB', 'State_PY',
#        'State_RJ', 'State_TN', 'State_TR', 'State_UC', 'State_UP', 'State_WB',
#        'Dealer Type_ASC', 'Dealer Type_DEALER', 'Product Type_EB',
#        'Product Type_MC', 'Product Type_MO', 'Product Type_SC', 'Gender_F',
#        'Gender_M', 'Qualification_HSC', 'Qualification_OTHERS',
#        'Qualification_PG', 'Qualification_SSC', 'Qualification_UG',
# ...

# %%
X=df_new1[['Tenure', 'Rate Of Interest', 'EMI', 'Processing Fee',
       'Asset Cost', 'Loan Amount', 'Age', 'Net Salary',
       'Net Internal Rate of Return', 'area_risk',
       'pin_risk', 'no_of_days', 'Payment type_ACH', 'Payment type_ADM',
       'Payment type_DAS', 'Payment type_DRE', 'Payment type_ENCH',
       'Payment type_PDC', 'State_AP', 'State_AS', 'State_BR', 'State_CG',
       'State_CH', 'State_DL', 'State_GJ', 'State_HA', 'State_HP', 'State_JH',
       'State_JK', 'State_KA', 'State_KL', 'State_MH', 'State_MN', 'State_MP',
       'State_OR', 'State_PB', 'State_PY', 'State_RJ', 'State_TN', 'State_TR',
       'State_UC', 'State_UP', 'State_WB', 'Dealer Type_ASC',
       'Dealer Type_DEALER', 'Product Type_EB', 'Product Type_MC',
       'Product Type_MO', 'Product Type_SC', 'Gender_F', 'Gender_M',
       'Qualification_HSC', 'Qualification_OTHERS', 'Qualification_PG',
       'Qualification_SSC', 'Qualification_UG', 'Employement Type_AGR',
       'Employement Type_HOW', 'Employement Type_OTH', 'Employement Type_PEN',
       'Employement Type_SAL', 'Employement Type_SEP', 'Employement Type_STU',
       'Residence Type_L', 'Residence Type_O', 'Residence Type_R']]

# %%
y=df_new1['Target Variable'].values

# %%
X
# Out:
#          Tenure  Rate Of Interest       EMI  Processing Fee  Asset Cost  \
# 0      0.470588         -0.793282  0.124252       -0.093758       87000
# 1      0.352941         -0.952045  0.083863       -0.572295       61500
# 2      0.352941          0.318061  0.210079        0.913555       87000
# 3      0.352941         -1.309262  0.166511        0.649593       84000
# 4      0.352941         -0.713900  0.092091       -0.572295       61500
# ...         ...               ...       ...             ...         ...
# 11697  0.470588          0.476825  0.258508        1.427003      124300
# 11698  0.588235          0.631619  0.235976        1.740351      136643
# 11699  0.352941         -1.352922  0.088631        0.586583       61651
# 11700  0.470588          0.834042  0.219147        0.978268      129300
# 11701  0.352941         -1.352922  0.135004        1.213279       78377
#
#        Loan Amount       Age  Net Salary  Net Internal Rate of Return  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score,roc_curve, recall_score, precision_score, average_precision_score, f1_score, classification_report, accuracy_score, plot_roc_curve,RocCurveDisplay, plot_precision_recall_curve,confusion_matrix, plot_confusion_matrix

# %%
classifier=LogisticRegression(max_iter=5000)

# %%
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=5000)

# %%
plt.figure(figsize=(12, 8))
plot_roc_curve(classifier,X_test,y_test)

# %%
test_pred = classifier.predict(X_test)

# %%
accuracy_score(y_test,test_pred)
# Out:
# 0.864957264957265

# %%
test_prob = classifier.predict_proba(X_test)[:,1]

# %%
test_prob
# Out:
# array([0.12096417, 0.50706286, 0.12253001, ..., 0.77501437, 0.07497688,
#        0.19498245])

# %%
test_pred
# Out:
# array([0, 1, 0, ..., 1, 0, 0], dtype=int64)

# %%
print('Log loss = {:.5f}'.format(log_loss(y_test, test_prob)))
print('AUC = {:.5f}'.format(roc_auc_score(y_test, test_prob)))
print('Average Precision = {:.5f}'.format(average_precision_score(y_test, test_prob)))
print('\nUsing 0.5 as threshold:')
print('Accuracy = {:.5f}'.format(accuracy_score(y_test, test_pred)))
print('Precision = {:.5f}'.format(precision_score(y_test, test_pred)))
print('Recall = {:.5f}'.format(recall_score(y_test, test_pred)))
print('F1 score = {:.5f}'.format(f1_score(y_test, test_pred)))

print('\nClassification Report')
print(classification_report(y_test, test_pred))
# Out:
# Log loss = 0.38529
# AUC = 0.91677
# Average Precision = 0.71659
#
# Using 0.5 as threshold:
# Accuracy = 0.86496
# Precision = 0.35392
# Recall = 0.83929
# F1 score = 0.49788
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92      3230
#            1       0.35      0.84      0.50       280
#
#     accuracy                           0.86      3510
#    macro avg       0.67      0.85      0.71      3510
# weighted avg       0.93      0.86      0.89      3510

# %%
plot_confusion_matrix(classifier, X_test, y_test)

# %%
fpr,tpr,thresholds = roc_curve(y_test, test_prob)

# %%
thres = pd.DataFrame(data={'FPR': fpr, 'TPR': tpr,'thresholds':thresholds})

# %%
optimal_idx = np.argmax(tpr - fpr)

# %%
optimal_idx
# Out:
# 180

# %%
fpr
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.09597523e-04,
#        3.09597523e-04, 6.19195046e-04, 6.19195046e-04, 9.28792570e-04,
#        9.28792570e-04, 1.23839009e-03, 1.23839009e-03, 1.54798762e-03,
#        1.54798762e-03, 1.85758514e-03, 1.85758514e-03, 2.47678019e-03,
#        2.47678019e-03, 3.09597523e-03, 3.09597523e-03, 3.40557276e-03,
#        3.40557276e-03, 3.71517028e-03, 3.71517028e-03, 4.02476780e-03,
#        4.02476780e-03, 4.64396285e-03, 4.64396285e-03, 5.57275542e-03,
#        5.57275542e-03, 6.50154799e-03, 6.50154799e-03, 8.04953560e-03,
#        8.04953560e-03, 8.35913313e-03, 8.35913313e-03, 8.66873065e-03,
#        8.66873065e-03, 1.02167183e-02, 1.02167183e-02, 1.05263158e-02,
#        1.05263158e-02, 1.11455108e-02, 1.11455108e-02, 1.33126935e-02,
#        1.33126935e-02, 1.36222910e-02, 1.36222910e-02, 1.39318885e-02,
#        1.39318885e-02, 1.45510836e-02, 1.45510836e-02, 1.48606811e-02,
# ...

# %%
thres.iloc[174]
# Out:
# FPR           0.117028
# TPR           0.825000
# thresholds    0.529831
# Name: 174, dtype: float64

# %%
sns.lineplot(x=thres['FPR'],y=thres['TPR'])
# Out:
# <AxesSubplot:xlabel='FPR', ylabel='TPR'>

# %%
thresholdlist=np.arange(0,1,0.05)

# %%
thresholdlist=[0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95,0.99]

# %%
pred_proba_df = pd.DataFrame(classifier.predict_proba(X_test))

# %%
tshl=[]
acc=[]
precision=[]
tprate=[]
fprate=[]
f1score=[]
CM=[]
Specificity=[]
p = {'Threshold':tshl,'Accuracy':acc,'Precision':precision,'TPR':tprate,'FPR':fprate,'F1':f1score,'Specificity' : Specificity,'CM':CM}

# %%
for i in thresholdlist:
    print ('\n******** For i = {} ******'.format(i))
    y_test_pred = pred_proba_df.applymap(lambda x: 1 if x>i else 0)
    test_accuracy = accuracy_score(y_test,y_test_pred.iloc[:,1])
    
    print('Our testing accuracy is {}'.format(test_accuracy))
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_test_pred.iloc[:,1])))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_test_pred.iloc[:,1])))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_test_pred.iloc[:,1])))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_test_pred.iloc[:,1])))
    print(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
    FPR = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    Specificity = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    print('FPR {}'.format(FPR))
    p['Threshold'].append(i)
    p['Accuracy'].append(accuracy_score(y_test,y_test_pred.iloc[:,1]))
    p['Precision'].append(precision_score(y_test,y_test_pred.iloc[:,1]))
    p['TPR'].append(recall_score(y_test,y_test_pred.iloc[:,1]))
    p['FPR'].append(FPR)
    p['Specificity'].append(Specificity)
    p['F1'].append(f1_score(y_test,y_test_pred.iloc[:,1]))
    p['CM'].append(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
# Out:
# ******** For i = 0.05 ******
# Our testing accuracy is 0.10683760683760683
# Accuracy = 0.10684
# Precision = 0.08199
# Recall = 1.00000
# F1 score = 0.15156
# [[  95 3135]
#  [   0  280]]
# FPR 0.9705882352941176
#
# ******** For i = 0.1 ******
# Our testing accuracy is 0.19943019943019943
# Accuracy = 0.19943
# Precision = 0.08982
# Recall = 0.98929
# F1 score = 0.16468
# [[ 423 2807]
#  [   3  277]]
# FPR 0.8690402476780186
#
# ******** For i = 0.15 ******
# Our testing accuracy is 0.34586894586894584
# Accuracy = 0.34587
# Precision = 0.10656
# Recall = 0.97500
# F1 score = 0.19212
# [[ 941 2289]
#  [   7  273]]
# FPR 0.7086687306501548
#
# ******** For i = 0.2 ******
# Our testing accuracy is 0.49743589743589745
# Accuracy = 0.49744
# Precision = 0.13304
# Recall = 0.96071
# F1 score = 0.23371
# [[1477 1753]
#  [  11  269]]
# FPR 0.5427244582043343
#
# ******** For i = 0.25 ******
# Our testing accuracy is 0.6193732193732193
# Accuracy = 0.61937
# Precision = 0.16540
# ...

# %%
tryy=pd.DataFrame(p)

# %%
pd.DataFrame(p)
# Out:
#     Threshold  Accuracy  Precision       TPR       FPR        F1  Specificity  \
# 0        0.05  0.106838   0.081991  1.000000  0.970588  0.151556     0.029412
# 1        0.10  0.199430   0.089818  0.989286  0.869040  0.164685     0.130960
# 2        0.15  0.345869   0.106557  0.975000  0.708669  0.192118     0.291331
# 3        0.20  0.497436   0.133037  0.960714  0.542724  0.233710     0.457276
# 4        0.25  0.619373   0.165399  0.932143  0.407740  0.280947     0.592260
# 5        0.30  0.705413   0.201741  0.910714  0.312384  0.330311     0.687616
# 6        0.35  0.762108   0.236967  0.892857  0.249226  0.374532     0.750774
# 7        0.40  0.809117   0.279412  0.882143  0.197214  0.424399     0.802786
# 8        0.45  0.840741   0.317169  0.864286  0.161300  0.464046     0.838700
# 9        0.50  0.864957   0.353916  0.839286  0.132817  0.497881     0.867183
# 10       0.55  0.886040   0.395833  0.814286  0.107740  0.532710     0.892260
# ...

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='Threshold',y='TPR',data=tryy.iloc[5:,:-1],color='red')
sns.lineplot(x='Threshold',y='Specificity',data=tryy.iloc[5:,:-1],color='green')
# Out:
# <AxesSubplot:xlabel='Threshold', ylabel='TPR'>

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtclassifier = DecisionTreeClassifier()

# %%
dtclassifier = dtclassifier.fit(X_train,y_train)

# %%
y_pred = dtclassifier.predict(X_test)

# %%
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
    print(confusion_matrix(y_test,y_pred))
    FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    print('FPR {}'.format(FPR))
    print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.92707
# Precision = 0.54110
# Recall = 0.56429
# F1 score = 0.55245
# [[3096  134]
#  [ 122  158]]
# FPR 0.04148606811145511
# Specificity 0.958513931888545

# %%
dtclassifier = DecisionTreeClassifier(criterion='entropy')

# %%
dtclassifier = dtclassifier.fit(X_train,y_train)

# %%
y_pred = dtclassifier.predict(X_test)

# %%
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
    print(confusion_matrix(y_test,y_pred))
    FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    print('FPR {}'.format(FPR))
    print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.92963
# Precision = 0.55593
# Recall = 0.58571
# F1 score = 0.57043
# [[3099  131]
#  [ 116  164]]
# FPR 0.04055727554179567
# Specificity 0.9594427244582043

# %% [markdown]
# ## Oversampling

# %%
# example of random oversampling to balance the class distribution
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler

# summarize class distribution
print(Counter(y_train))
# define oversampling strategy
oversample = RandomOverSampler(sampling_strategy='minority')
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X_train, y_train)
# summarize class distribution
print(Counter(y_over))
# Out:
# Counter({0: 7592, 1: 596})
# Counter({0: 7592, 1: 7592})

# %%
classifier=LogisticRegression(max_iter=5000)
classifier.fit(X_over,y_over)
plt.figure(figsize=(12, 8))
plot_roc_curve(classifier,X_over,y_over)

# %%
test_pred = classifier.predict(X_test)
test_prob = classifier.predict_proba(X_test)[:,1]

# %%
print('Log loss = {:.5f}'.format(log_loss(y_test, test_prob)))
print('AUC = {:.5f}'.format(roc_auc_score(y_test, test_prob)))
print('Average Precision = {:.5f}'.format(average_precision_score(y_test, test_prob)))
print('\nUsing 0.5 as threshold:')
print('Accuracy = {:.5f}'.format(accuracy_score(y_test, test_pred)))
print('Precision = {:.5f}'.format(precision_score(y_test, test_pred)))
print('Recall = {:.5f}'.format(recall_score(y_test, test_pred)))
print('F1 score = {:.5f}'.format(f1_score(y_test, test_pred)))

print('\nClassification Report')
print(classification_report(y_test, test_pred))
# Out:
# Log loss = 0.38529
# AUC = 0.91677
# Average Precision = 0.71659
#
# Using 0.5 as threshold:
# Accuracy = 0.86496
# Precision = 0.35392
# Recall = 0.83929
# F1 score = 0.49788
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.87      0.92      3230
#            1       0.35      0.84      0.50       280
#
#     accuracy                           0.86      3510
#    macro avg       0.67      0.85      0.71      3510
# weighted avg       0.93      0.86      0.89      3510

# %%
plt.figure(figsize=(12, 12))
plot_confusion_matrix(classifier, X_test, y_test)

# %%
fpr,tpr,thresholds = roc_curve(y_test, test_prob)

# %%
thres = pd.DataFrame(data={'FPR': fpr, 'TPR': tpr,'thresholds':thresholds})

# %%
optimal_idx = np.argmax(tpr - fpr)

# %%
optimal_idx
# Out:
# 180

# %%
thres.iloc[164]
# Out:
# FPR           0.103715
# TPR           0.807143
# thresholds    0.558709
# Name: 164, dtype: float64

# %%
sns.lineplot(x=thres['FPR'],y=thres['TPR'])
# Out:
# <AxesSubplot:xlabel='FPR', ylabel='TPR'>

# %%
thresholdlist=np.arange(0,1,0.05)

# %%
pred_proba_df = pd.DataFrame(classifier.predict_proba(X_test))

# %%
tshl=[]
acc=[]
precision=[]
tprate=[]
fprate=[]
f1score=[]
CM=[]
Specificity=[]
p = {'Threshold':tshl,'Accuracy':acc,'Precision':precision,'TPR':tprate,'FPR':fprate,'F1':f1score,'Specificity' : Specificity,'CM':CM}

# %%
for i in thresholdlist:
    print ('\n******** For i = {} ******'.format(i))
    y_test_pred = pred_proba_df.applymap(lambda x: 1 if x>i else 0)
    test_accuracy = accuracy_score(y_test,y_test_pred.iloc[:,1])
    
    print('Our testing accuracy is {}'.format(test_accuracy))
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_test_pred.iloc[:,1])))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_test_pred.iloc[:,1])))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_test_pred.iloc[:,1])))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_test_pred.iloc[:,1])))
    print(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
    FPR = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    Specificity = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    print('FPR {}'.format(FPR))
    p['Threshold'].append(i)
    p['Accuracy'].append(accuracy_score(y_test,y_test_pred.iloc[:,1]))
    p['Precision'].append(precision_score(y_test,y_test_pred.iloc[:,1]))
    p['TPR'].append(recall_score(y_test,y_test_pred.iloc[:,1]))
    p['FPR'].append(FPR)
    p['Specificity'].append(Specificity)
    p['F1'].append(f1_score(y_test,y_test_pred.iloc[:,1]))
    p['CM'].append(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
# Out:
# ******** For i = 0.0 ******
# Our testing accuracy is 0.07977207977207977
# Accuracy = 0.07977
# Precision = 0.07977
# Recall = 1.00000
# F1 score = 0.14776
# [[   0 3230]
#  [   0  280]]
# FPR 1.0
#
# ******** For i = 0.05 ******
# Our testing accuracy is 0.10683760683760683
# Accuracy = 0.10684
# Precision = 0.08199
# Recall = 1.00000
# F1 score = 0.15156
# [[  95 3135]
#  [   0  280]]
# FPR 0.9705882352941176
#
# ******** For i = 0.1 ******
# Our testing accuracy is 0.19943019943019943
# Accuracy = 0.19943
# Precision = 0.08982
# Recall = 0.98929
# F1 score = 0.16468
# [[ 423 2807]
#  [   3  277]]
# FPR 0.8690402476780186
#
# ******** For i = 0.15000000000000002 ******
# Our testing accuracy is 0.34586894586894584
# Accuracy = 0.34587
# Precision = 0.10656
# Recall = 0.97500
# F1 score = 0.19212
# [[ 941 2289]
#  [   7  273]]
# FPR 0.7086687306501548
#
# ******** For i = 0.2 ******
# Our testing accuracy is 0.49743589743589745
# Accuracy = 0.49744
# Precision = 0.13304
# ...

# %%
pd.DataFrame(p)
# Out:
#     Threshold  Accuracy  Precision       TPR       FPR        F1  Specificity  \
# 0        0.00  0.079772   0.079772  1.000000  1.000000  0.147757     0.000000
# 1        0.05  0.106838   0.081991  1.000000  0.970588  0.151556     0.029412
# 2        0.10  0.199430   0.089818  0.989286  0.869040  0.164685     0.130960
# 3        0.15  0.345869   0.106557  0.975000  0.708669  0.192118     0.291331
# 4        0.20  0.497436   0.133037  0.960714  0.542724  0.233710     0.457276
# 5        0.25  0.619373   0.165399  0.932143  0.407740  0.280947     0.592260
# 6        0.30  0.705413   0.201741  0.910714  0.312384  0.330311     0.687616
# 7        0.35  0.762108   0.236967  0.892857  0.249226  0.374532     0.750774
# 8        0.40  0.809117   0.279412  0.882143  0.197214  0.424399     0.802786
# 9        0.45  0.840741   0.317169  0.864286  0.161300  0.464046     0.838700
# 10       0.50  0.864957   0.353916  0.839286  0.132817  0.497881     0.867183
# ...

# %% [markdown]
# ### The best threshold looks like 0.35

# %%
y_pred_with_threshold = (test_prob >= 0.35).astype(int)

# %%
y_pred_with_threshold
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
pd.crosstab(y_test,y_pred_with_threshold)
# Out:
# col_0     0    1
# row_0
# 0      2805  425
# 1        30  250

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(x='Threshold',y='TPR',data=tryy.iloc[5:,:-1],color='red')
sns.lineplot(x='Threshold',y='Specificity',data=tryy.iloc[5:,:-1],color='green')
# Out:
# <AxesSubplot:xlabel='Threshold', ylabel='TPR'>

# %%
dtclassifier = DecisionTreeClassifier(criterion='entropy')

# %%
dtclassifier = dtclassifier.fit(X_over,y_over)

# %%
y_pred = dtclassifier.predict(X_test)

# %%
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
    print(confusion_matrix(y_test,y_pred))
    FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    print('FPR {}'.format(FPR))
    print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.93219
# Precision = 0.57447
# Recall = 0.57857
# F1 score = 0.57651
# [[3110  120]
#  [ 118  162]]
# FPR 0.03715170278637771
# Specificity 0.9628482972136223

# %% [markdown]
# ## Oversampling and Undersampling combined

# %%
from imblearn.under_sampling import RandomUnderSampler
# summarize class distribution
print(Counter(y_train))
# define oversampling strategy
oversample = RandomOverSampler(sampling_strategy=0.6)
# fit and apply the transform
X_over, y_over = oversample.fit_resample(X_train, y_train)
# summarize class distribution
print(Counter(y_over))
# define undersample strategy
undersample = RandomUnderSampler(sampling_strategy='majority')
# fit and apply the transform
X_under, y_under = undersample.fit_resample(X_over, y_over)
# summarize class distribution
print(Counter(y_under))
# Out:
# Counter({0: 7592, 1: 596})
# Counter({0: 7592, 1: 4555})
# Counter({0: 4555, 1: 4555})

# %%
classifier=LogisticRegression(max_iter=5000)
classifier.fit(X_under,y_under)
plt.figure(figsize=(12, 8))
plot_roc_curve(classifier,X_test,y_test)

# %%
test_pred = classifier.predict(X_test)
test_prob = classifier.predict_proba(X_test)[:,1]

# %%
print('Log loss = {:.5f}'.format(log_loss(y_test, test_prob)))
print('AUC = {:.5f}'.format(roc_auc_score(y_test, test_prob)))
print('Average Precision = {:.5f}'.format(average_precision_score(y_test, test_prob)))
print('\nUsing 0.5 as threshold:')
print('Accuracy = {:.5f}'.format(accuracy_score(y_test, test_pred)))
print('Precision = {:.5f}'.format(precision_score(y_test, test_pred)))
print('Recall = {:.5f}'.format(recall_score(y_test, test_pred)))
print('F1 score = {:.5f}'.format(f1_score(y_test, test_pred)))

print('\nClassification Report')
print(classification_report(y_test, test_pred))
# Out:
# Log loss = 0.39656
# AUC = 0.91685
# Average Precision = 0.71585
#
# Using 0.5 as threshold:
# Accuracy = 0.85783
# Precision = 0.34199
# Recall = 0.84643
# F1 score = 0.48715
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.92      3230
#            1       0.34      0.85      0.49       280
#
#     accuracy                           0.86      3510
#    macro avg       0.66      0.85      0.70      3510
# weighted avg       0.93      0.86      0.88      3510

# %%
plot_confusion_matrix(classifier, X_test, y_test)

# %%
fpr,tpr,thresholds = roc_curve(y_test, test_prob)

# %%
thres = pd.DataFrame(data={'FPR': fpr, 'TPR': tpr,'thresholds':thresholds})

# %%
optimal_idx = np.argmax(tpr - fpr)

# %%
optimal_idx
# Out:
# 176

# %%
thres.iloc[176]
# Out:
# FPR           0.118266
# TPR           0.832143
# thresholds    0.539528
# Name: 176, dtype: float64

# %%
sns.lineplot(x=thres['FPR'],y=thres['TPR'])
# Out:
# <AxesSubplot:xlabel='FPR', ylabel='TPR'>

# %%
thresholdlist=np.arange(0,1,0.05)

# %%
pred_proba_df = pd.DataFrame(classifier.predict_proba(X_test))

# %%
tshl=[]
acc=[]
precision=[]
tprate=[]
fprate=[]
f1score=[]
CM=[]
Specificity=[]
p = {'Threshold':tshl,'Accuracy':acc,'Precision':precision,'TPR':tprate,'FPR':fprate,'F1':f1score,'Specificity' : Specificity,'CM':CM}

# %%
for i in thresholdlist:
    print ('\n******** For i = {} ******'.format(i))
    y_test_pred = pred_proba_df.applymap(lambda x: 1 if x>i else 0)
    test_accuracy = accuracy_score(y_test,y_test_pred.iloc[:,1])
    
    print('Our testing accuracy is {}'.format(test_accuracy))
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_test_pred.iloc[:,1])))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_test_pred.iloc[:,1])))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_test_pred.iloc[:,1])))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_test_pred.iloc[:,1])))
    print(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
    FPR = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    Specificity = confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] /(confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][0] + confusion_matrix(y_test, y_test_pred.iloc[:,1])[0][1])
    print('FPR {}'.format(FPR))
    p['Threshold'].append(i)
    p['Accuracy'].append(accuracy_score(y_test,y_test_pred.iloc[:,1]))
    p['Precision'].append(precision_score(y_test,y_test_pred.iloc[:,1]))
    p['TPR'].append(recall_score(y_test,y_test_pred.iloc[:,1]))
    p['FPR'].append(FPR)
    p['Specificity'].append(Specificity)
    p['F1'].append(f1_score(y_test,y_test_pred.iloc[:,1]))
    p['CM'].append(confusion_matrix(y_test,y_test_pred.iloc[:,1]))
# Out:
# ******** For i = 0.0 ******
# Our testing accuracy is 0.07977207977207977
# Accuracy = 0.07977
# Precision = 0.07977
# Recall = 1.00000
# F1 score = 0.14776
# [[   0 3230]
#  [   0  280]]
# FPR 1.0
#
# ******** For i = 0.05 ******
# Our testing accuracy is 0.10227920227920229
# Accuracy = 0.10228
# Precision = 0.08161
# Recall = 1.00000
# F1 score = 0.15090
# [[  79 3151]
#  [   0  280]]
# FPR 0.9755417956656347
#
# ******** For i = 0.1 ******
# Our testing accuracy is 0.18888888888888888
# Accuracy = 0.18889
# Precision = 0.08875
# Recall = 0.98929
# F1 score = 0.16289
# [[ 386 2844]
#  [   3  277]]
# FPR 0.8804953560371517
#
# ******** For i = 0.15000000000000002 ******
# Our testing accuracy is 0.335042735042735
# Accuracy = 0.33504
# Precision = 0.10500
# Recall = 0.97500
# F1 score = 0.18958
# [[ 903 2327]
#  [   7  273]]
# FPR 0.7204334365325077
#
# ******** For i = 0.2 ******
# Our testing accuracy is 0.4811965811965812
# Accuracy = 0.48120
# Precision = 0.12939
# ...

# %%
pd.DataFrame(p)
# Out:
#     Threshold  Accuracy  Precision       TPR       FPR        F1  Specificity  \
# 0        0.00  0.079772   0.079772  1.000000  1.000000  0.147757     0.000000
# 1        0.05  0.102279   0.081609  1.000000  0.975542  0.150903     0.024458
# 2        0.10  0.188889   0.088754  0.989286  0.880495  0.162893     0.119505
# 3        0.15  0.335043   0.105000  0.975000  0.720433  0.189583     0.279567
# 4        0.20  0.481197   0.129389  0.960714  0.560372  0.228063     0.439628
# 5        0.25  0.604843   0.160638  0.935714  0.423839  0.274202     0.576161
# 6        0.30  0.692877   0.194954  0.910714  0.326006  0.321159     0.673994
# 7        0.35  0.751567   0.229927  0.900000  0.261300  0.366279     0.738700
# 8        0.40  0.800000   0.270153  0.885714  0.207430  0.414023     0.792570
# 9        0.45  0.834188   0.307888  0.864286  0.168421  0.454034     0.831579
# 10       0.50  0.857835   0.341991  0.846429  0.141176  0.487153     0.858824
# ...

# %%
dtclassifier = DecisionTreeClassifier(criterion='entropy')

# %%
dtclassifier = dtclassifier.fit(X_under,y_under)

# %%
y_pred = dtclassifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
    print(confusion_matrix(y_test,y_pred))
    FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    print('FPR {}'.format(FPR))
    print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.91083
# Precision = 0.45646
# Recall = 0.61786
# F1 score = 0.52504
# [[3024  206]
#  [ 107  173]]
# FPR 0.06377708978328174
# Specificity 0.9362229102167182

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
y_under
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
rf = rf.fit(X_under,y_under)

# %%
y_predt = rf.predict(X_test)

# %%
y_predt
# Out:
# array([0.  , 0.27, 0.1 , ..., 0.64, 0.  , 0.01])

# %%
y_pred = (y_predt >= 0.2).astype(int)

# %%
    print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
    print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
    print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
    print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
    print(confusion_matrix(y_test,y_pred))
    FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
    print('FPR {}'.format(FPR))
    print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.88803
# Precision = 0.40536
# Recall = 0.86429
# F1 score = 0.55188
# [[2875  355]
#  [  38  242]]
# FPR 0.10990712074303406
# Specificity 0.8900928792569659

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf = clf.fit(X_under, y_under)

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
print('Accuracy = {:.5f}'.format(accuracy_score(y_test,y_pred)))
print('Precision = {:.5f}'.format(precision_score(y_test,y_pred)))
print('Recall = {:.5f}'.format(recall_score(y_test,y_pred)))
print('F1 score = {:.5f}'.format(f1_score(y_test,y_pred)))
print(confusion_matrix(y_test,y_pred))
FPR = confusion_matrix(y_test, y_pred)[0][1] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
Specificity = confusion_matrix(y_test, y_pred)[0][0] /(confusion_matrix(y_test, y_pred)[0][0] + confusion_matrix(y_test, y_pred)[0][1])
print('FPR {}'.format(FPR))
print('Specificity {}'.format(Specificity))
# Out:
# Accuracy = 0.93761
# Precision = 0.58790
# Recall = 0.72857
# F1 score = 0.65072
# [[3087  143]
#  [  76  204]]
# FPR 0.04427244582043344
# Specificity 0.9557275541795666

# %%
df
# Out:
#        Customer ID Date of disbursal of loan Payment type Area Code Pin Code  \
# 0                0                2020-02-13          ACH      3075   530041
# 1                1                2020-06-02          ADM      3075   532123
# 2                2                2020-10-02          ADM      3075   533218
# 3                3                2020-10-02          ADM      3075   532484
# 4                4                2020-10-02          ADM      3075   530046
# ...            ...                       ...          ...       ...      ...
# 11697        11697                2021-02-28          ADM      3052   245101
# 11698        11698                2021-02-28          ACH      3052   250002
# 11699        11699                2021-02-28          ACH      3052   250401
# 11700        11700                2021-09-02          ACH      3074   244601
# 11701        11701                2021-02-02          ADM      3074   244221
#
# ...

# %%
df.to_csv('tvs_credit_cleaned.csv',index=False)
